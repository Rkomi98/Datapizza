# %%
import os
from dotenv import load_dotenv
from datapizzai.clients import ClientFactory
from datapizzai.type import TextBlock

# Carica variabili da .env (root progetto)
load_dotenv()

client = ClientFactory.create(
    provider="openai",
    api_key=os.getenv("OPENAI_API_KEY"),
    model="gpt-5",
    temperature=1
)

# Invoke sempplice (minimale)
print(client.invoke("Ciao, piacere di conoscerti").text)

# Oppure usando un modulo che vedremo tra un attimo
print(client.invoke(TextBlock(content="Ciao, piacere di conoscerti")).text)
# Out:
# Ciao! Piacere mio. Come posso aiutarti oggi?
# Ciao! Piacere di conoscerti anche per me. Come posso aiutarti oggi?

# %%
from datapizzai.memory import Memory
from datapizzai.type import TextBlock, ROLE

memory = Memory()

# Aggiunta di un turno utente
memory.add_turn([TextBlock(content="Ciao, sono Mirko")], ROLE.USER)

# Invocazione con contesto
response = client.invoke("", memory=memory)
# Salvataggio risposta (usa SEMPRE una stringa)
memory.add_turn([TextBlock(content=response.text)], ROLE.ASSISTANT)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       7 memory.add_turn([TextBlock(content="Ciao, sono Mirko")], ROLE.USER)
#       9 # Invocazione con contesto
# ---> 10 response = client.invoke(memory=memory)
#      11 # Salvataggio risposta (usa SEMPRE una stringa)
#      12 memory.add_turn([TextBlock(content=response.text)], ROLE.ASSISTANT)
#
# File ~/Documenti/GitHub/Datapizza/DatapizzAI/PizzAI/.venv/lib/python3.12/site-packages/datapizzai/cache/cache.py:91, in cacheable.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      88 @wraps(func)
#      89 def wrapper(self, *args, **kwargs):
#      90     if not self.cache:
# ---> 91         return func(self, *args, **kwargs)
#      93     try:
#      94         # Get all arguments as a dictionary
#      95         bound_args = kwargs.copy()
#
# TypeError: Client.invoke() missing 1 required positional argument: 'input'
